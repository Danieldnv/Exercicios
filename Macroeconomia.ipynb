# %% [markdown]
# <a href="https://colab.research.google.com/github/Danieldnv/Exercicios/blob/main/Macroeconomia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from pandas_datareader import data as pdr
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
# !pip install yfinance --upgrade --no-cache-dir
import yfinance as yf
yf.pdr_override()
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
PETR4= pdr.get_data_yahoo("PETR4.SA")
BOVA11= pdr.get_data_yahoo("BOVA11.SA")
TAEE11= pdr.get_data_yahoo("TAEE11.SA")
VIIA3= pdr.get_data_yahoo("VIIA3.SA")

BOVA11["Close"].plot(figsize=(20,5), label= 'ETF que replica o Ibovespa (BOVA11)', color='red')
TAEE11["Close"].plot(label= "Taesa (TAEE11)", color ='yellowgreen')
PETR4['Close'].plot(label= 'Petrobrás (PETR4)', color= 'mediumturquoise')
VIIA3['Close'].plot(label='Via (VIIA3)', color='cornflowerblue')
plt.legend()
plt.title("Comparando ações com o ETF BOVA11", size=16)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Text(0.5, 1.0, 'Comparando ações com o ETF BOVA11')
